# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
from math import sqrt   
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

if __name__ == '__main__':
    df_train=pd.read_csv("scaffold_train_ECFP.csv")
    df_valid=pd.read_csv("scaffold_valid_ECFP.csv")
    df_test=pd.read_csv("scaffold_test_ECFP.csv")
    ECFP4_column_lis = [i for i in df_train.columns if 'ECFP_4' in i]
    X_train = np.array(df_train[ECFP4_column_lis])
    X_val = np.array(df_valid[ECFP4_column_lis])
    X_test = np.array(df_test[ECFP4_column_lis])
    y_train = np.array(df_train['standard_value'])
    y_val = np.array(df_valid['standard_value'])
    y_test = np.array(df_test['standard_value'])
    layers_list = [(100,100),(150,150),(250,250),(400,400),(600,600),(800,800),       
          (100,100,100),(150,150,150),(250,250,250),(400,400,400),(600,600,600),(800,800,800),
          (100,100,100,100),(150,150,150,150),(250,250,250,250),(400,400,400,400),(600,600,600,600),(800,800,800,800)]   
    alpha_list = [0.00003,0.0001,0.0003,0.001,0.003]
    result_MAE = []
    result_RMSE = []
    result_R2 = []
    log_lis = []
    best_mae=1000
    best_R2=-1
    best_RMSE=1000
    best_alpha=-1
    # best_max_depth=-1
    # best_min_sample=-1
    for layers in layers_list:
        for alpha in alpha_list:
            print('layer: '+ str(layers))
            print('alpha: '+ str(alpha))
            print('')
            print(' ')
            model = MLPRegressor(layers,alpha = alpha)
            model.fit(X_train, y_train)
            y_pred = model.predict(X_val)
            MAE = mean_absolute_error(y_val,y_pred)
            RMSE = sqrt(mean_squared_error(y_val,y_pred))
            R2 = r2_score(y_val,y_pred)
            if MAE<best_mae:
                best_alpha=alpha
                best_layer=layers
                best_mae=MAE
                best_R2=R2
                best_RMSE=RMSE
            result_MAE.append(MAE)
            result_RMSE.append(RMSE)
            result_R2.append(R2)
    
print("best mae: ",best_mae)
print("best RMSE: ",best_RMSE)
print("best R2: ",best_R2)
print("best alpha: ",alpha)
print("best layer: ",layers)
# Out:
# layer: (100, 100)
# alpha: 3e-05
#
#
# layer: (100, 100)
# alpha: 0.0001
#
#
# layer: (100, 100)
# alpha: 0.0003
#
#
# layer: (100, 100)
# alpha: 0.001
#
#
# layer: (100, 100)
# alpha: 0.003
#
#
# layer: (150, 150)
# alpha: 3e-05
#
#
# layer: (150, 150)
# alpha: 0.0001
#
#
# layer: (150, 150)
# alpha: 0.0003
#
#
# layer: (150, 150)
# alpha: 0.001
#
#
# layer: (150, 150)
# alpha: 0.003
#
#
# layer: (250, 250)
# alpha: 3e-05
#
#
# layer: (250, 250)
# alpha: 0.0001
#
#
# layer: (250, 250)
# alpha: 0.0003
#
#
# layer: (250, 250)
# alpha: 0.001
#
#
# layer: (250, 250)
# alpha: 0.003
#
#
# layer: (400, 400)
# alpha: 3e-05
#
#
# layer: (400, 400)
# alpha: 0.0001
#
#
# layer: (400, 400)
# alpha: 0.0003
#
#
# layer: (400, 400)
# alpha: 0.001
#
#
# layer: (400, 400)
# alpha: 0.003
#
#
# layer: (600, 600)
# alpha: 3e-05
#
#
# layer: (600, 600)
# alpha: 0.0001
#
#
# layer: (600, 600)
# alpha: 0.0003
#
#
# layer: (600, 600)
# alpha: 0.001
#
#
# layer: (600, 600)
# alpha: 0.003
#
#
# layer: (800, 800)
# alpha: 3e-05
#
#
# layer: (800, 800)
# alpha: 0.0001
#
#
# layer: (800, 800)
# alpha: 0.0003
#
#
# layer: (800, 800)
# alpha: 0.001
#
#
# layer: (800, 800)
# alpha: 0.003
#
#
# layer: (100, 100, 100)
# alpha: 3e-05
#
#
# layer: (100, 100, 100)
# alpha: 0.0001
#
#
# layer: (100, 100, 100)
# alpha: 0.0003
#
#
# layer: (100, 100, 100)
# alpha: 0.001
#
#
# layer: (100, 100, 100)
# alpha: 0.003
#
#
# layer: (150, 150, 150)
# alpha: 3e-05
#
#
# layer: (150, 150, 150)
# alpha: 0.0001
#
#
# layer: (150, 150, 150)
# alpha: 0.0003
#
#
# layer: (150, 150, 150)
# alpha: 0.001
#
#
# layer: (150, 150, 150)
# alpha: 0.003
#
#
# layer: (250, 250, 250)
# alpha: 3e-05
#
#
# layer: (250, 250, 250)
# alpha: 0.0001
#
#
# layer: (250, 250, 250)
# alpha: 0.0003
#
#
# layer: (250, 250, 250)
# alpha: 0.001
#
#
# layer: (250, 250, 250)
# alpha: 0.003
#
#
# layer: (400, 400, 400)
# alpha: 3e-05
#
#
# layer: (400, 400, 400)
# alpha: 0.0001
#
#
# layer: (400, 400, 400)
# alpha: 0.0003
#
#
# layer: (400, 400, 400)
# alpha: 0.001
#
#
# layer: (400, 400, 400)
# alpha: 0.003
#
#
# layer: (600, 600, 600)
# alpha: 3e-05
#
#
# layer: (600, 600, 600)
# alpha: 0.0001
#
#
# layer: (600, 600, 600)
# alpha: 0.0003
#
#
# layer: (600, 600, 600)
# alpha: 0.001
#
#
# layer: (600, 600, 600)
# alpha: 0.003
#
#
# layer: (800, 800, 800)
# alpha: 3e-05
#
#
# layer: (800, 800, 800)
# alpha: 0.0001
#
#
# layer: (800, 800, 800)
# alpha: 0.0003
#
#
# layer: (800, 800, 800)
# alpha: 0.001
#
#
# layer: (800, 800, 800)
# alpha: 0.003
#
#
# layer: (100, 100, 100, 100)
# alpha: 3e-05
#
#
# layer: (100, 100, 100, 100)
# alpha: 0.0001
#
#
# layer: (100, 100, 100, 100)
# alpha: 0.0003
#
#
# layer: (100, 100, 100, 100)
# alpha: 0.001
#
#
# layer: (100, 100, 100, 100)
# alpha: 0.003
#
#
# layer: (150, 150, 150, 150)
# alpha: 3e-05
#
#
# layer: (150, 150, 150, 150)
# alpha: 0.0001
#
#
# layer: (150, 150, 150, 150)
# alpha: 0.0003
#
#
# layer: (150, 150, 150, 150)
# alpha: 0.001
#
#
# layer: (150, 150, 150, 150)
# alpha: 0.003
#
#
# layer: (250, 250, 250, 250)
# alpha: 3e-05
#
#
# layer: (250, 250, 250, 250)
# alpha: 0.0001
#
#
# layer: (250, 250, 250, 250)
# alpha: 0.0003
#
#
# layer: (250, 250, 250, 250)
# alpha: 0.001
#
#
# layer: (250, 250, 250, 250)
# alpha: 0.003
#
#
# layer: (400, 400, 400, 400)
# alpha: 3e-05
#
#
# layer: (400, 400, 400, 400)
# alpha: 0.0001
#
#
# layer: (400, 400, 400, 400)
# alpha: 0.0003
#
#
# layer: (400, 400, 400, 400)
# alpha: 0.001
#
#
# layer: (400, 400, 400, 400)
# alpha: 0.003
#
#
# layer: (600, 600, 600, 600)
# alpha: 3e-05
#
#
# layer: (600, 600, 600, 600)
# alpha: 0.0001
#
#
# layer: (600, 600, 600, 600)
# alpha: 0.0003
#
#
# layer: (600, 600, 600, 600)
# alpha: 0.001
#
#
# layer: (600, 600, 600, 600)
# alpha: 0.003
#
#
# layer: (800, 800, 800, 800)
# alpha: 3e-05
#
#
# layer: (800, 800, 800, 800)
# alpha: 0.0001
#
#
# layer: (800, 800, 800, 800)
# alpha: 0.0003
#
#
# layer: (800, 800, 800, 800)
# alpha: 0.001
#
#
# layer: (800, 800, 800, 800)
# alpha: 0.003
#
#
# best mae:  0.6840017464904224
# best RMSE:  0.9415687967533047
# best R2:  0.6110655078611467
# best alpha:  0.003
# best layer:  (800, 800, 800, 800)

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
from math import sqrt   
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df_train=pd.read_csv("scaffold_train_ECFP.csv")
df_valid=pd.read_csv("scaffold_valid_ECFP.csv")
df_test=pd.read_csv("scaffold_test_ECFP.csv")
ECFP4_column_lis = [i for i in df_train.columns if 'ECFP_4' in i]
X_train = np.array(df_train[ECFP4_column_lis])
X_val = np.array(df_valid[ECFP4_column_lis])
X_test = np.array(df_test[ECFP4_column_lis])
y_train = np.array(df_train['standard_value'])
y_val = np.array(df_valid['standard_value'])
y_test = np.array(df_test['standard_value'])

# %%
model = MLPRegressor((800, 800, 800, 800),alpha = 0.003)
model.fit(X_train, y_train)
y_pred = model.predict(X_val)
MAE = mean_absolute_error(y_val,y_pred)
RMSE = sqrt(mean_squared_error(y_val,y_pred))
R2 = r2_score(y_val,y_pred)

# %%
import joblib


joblib.dump(model,"./ANN.pickle")
# Out:
# ['./ANN.pickle']

# %%
y_pred = model.predict(X_test)
from math import sqrt   
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import pandas as pd
print(round(sqrt(mean_squared_error(y_test, y_pred)),3))
print(round(mean_absolute_error(y_test, y_pred),3))
#print("mean_squared_error:", mean_squared_error(y_test, y_predict))

print(round(r2_score(y_test, y_pred),3))
# Out:
# 1.009
# 0.748
# 0.536
